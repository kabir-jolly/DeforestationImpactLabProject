# %% [markdown]
# # Project Setup and Data Loading

# %%
import pandas as pd
import numpy as np
import os
import math

# %%
performance_data_path = "./performance_data"
councils_path = os.path.join(performance_data_path, 'councils.csv')
mp_path = os.path.join(performance_data_path, 'management_plans.csv')
fires_path = os.path.join(performance_data_path, 'fires.csv')
visitation_sede_path = os.path.join(performance_data_path, 'visitation_cadastral_uc.csv')
visitation_total_mes_path = os.path.join(performance_data_path, 'visitation_dados_visitacao.csv')

# %%
performance_data_cols = ['council_status',
                        'council_creation_year',
                        'pa_creation_year_cmi',
                        'reg_coord_2021',
                        'munis_covered_cmi',
                        'biome_cmi',
                        'mp_cmi',
                        'mp_creation_year_cmi',
                        'mp_in_progress',
                        'mp_revised',
                        'management_muni_cmi',
                        'management_state_cmi',
                        'visitors',
                        'area_burned']

# %%
dict1 = {"CNUCA": [4, "PA", 0, ["name1", "name2", "name3"]],
        "CNUCB": [7, "PA", 1, ["name1", "name2", "name3"]],
        "CNUCC": [9, "PA", 0, ["name1", "name2", "name3"]]}
pd.DataFrame.from_dict(dict1, orient='index', columns=performance_data_cols[:4])
# Out:
#        council_status council_creation_year  pa_creation_year_cmi  \
# CNUCA               4                    PA                     0
# CNUCB               7                    PA                     1
# CNUCC               9                    PA                     0
#
#               reg_coord_2021
# CNUCA  [name1, name2, name3]
# CNUCB  [name1, name2, name3]
# CNUCC  [name1, name2, name3]

# %%
dict1["CNUCA"].append("Hello")
dict1
# Out:
# {'CNUCA': [4, 'PA', 0, ['name1', 'name2', 'name3'], 'Hello'],
#  'CNUCB': [7, 'PA', 1, ['name1', 'name2', 'name3']],
#  'CNUCC': [9, 'PA', 0, ['name1', 'name2', 'name3']]}

# %%
dict1["CNUCA"][2]=4000
dict1
# Out:
# {'CNUCA': [4, 'PA', 4000, ['name1', 'name2', 'name3'], 'Hello'],
#  'CNUCB': [7, 'PA', 1, ['name1', 'name2', 'name3']],
#  'CNUCC': [9, 'PA', 0, ['name1', 'name2', 'name3']]}

# %%
council_df_cols = ['Código CNUC',
                   'Nome da UC',
                   'Situação do Conselho\n(Instituído / Em formação / Inexistente)',
                   'Ano de instituição do Conselho\n(ano / NA)']
council_df = pd.read_csv(councils_path, encoding='latin-1', usecols=council_df_cols)
council_df.head()
# Out:
#     Código CNUC                                    Nome da UC  \
# 0  0000.00.0001                               APA Anhatomirim
# 1  0000.00.1521  APA Bacia Hidrográfica do Rio Paraíba do Sul
# 2  0000.00.0007                   APA Barra do Rio Mamanguape
# 3  0000.00.0020                     APA Carste da Lagoa Santa
# 4  0000.00.0002                       APA Cavernas do Peruaçu
#
#   Situação do Conselho\n(Instituído / Em formação / Inexistente)  \
# 0                                         Instituído
# 1                                        Em formação
# 2                                         Instituído
# 3                                         Instituído
# 4                                         Instituído
#
#    Ano de instituição do Conselho\n(ano / NA)
# 0                                      2008.0
# 1                                         NaN
# 2                                      2005.0
# 3                                      2005.0
# 4                                      2004.0

# %%
mp_df_cols = ['Código CNUC',
              'Nome da UC',
              'Ano de criação',
              'Coordenação Regional do ICMBio',
              'Municípios sobrepostos',
              'Bioma referencial (CGFUN)',
              'A UC possui plano de manejo (Sim / Não)',
              'Ano de elaboração do plano de manejo',
              'O plano de manejo está em elaboração? (Sim / Não / NA)',
              'O plano de manejo foi revisado? (Sim / Não / NA)',
             ]
mp_df = pd.read_csv(mp_path, encoding='latin-1', usecols=mp_df_cols)
mp_df.head()
# Out:
#     Código CNUC                                        Nome da UC  \
# 0  0000.00.0001                                   APA Anhatomirim
# 1  0000.00.0002                           APA Cavernas do Peruaçu
# 2  0000.00.0003                    APA da Bacia do Rio Descoberto
# 3  0000.00.0004                APA da Bacia do Rio São Bartolomeu
# 4  0000.00.0005  APA da Bacia do Rio São João - Mico-Leão-Dourado
#
#    Ano de criação Coordenação Regional do ICMBio  \
# 0            1992           CR9 Florianópolis/SC
# 1            1989            CR11 Lagoa Santa/MG
# 2            1983            CR11 Lagoa Santa/MG
# 3            1983            CR11 Lagoa Santa/MG
# 4            2002          CR8 Rio de Janeiro/RJ
#
#                               Municípios sobrepostos  \
# 0                             Governador Celso Ramos
# 1  Bonito de Minas, Cônego Marinho, Januária, Ita...
# 2    Brasília, Águas Lindas de Goiás, Padre Bernardo
# 3                                           Brasília
# 4  Silva Jardim, Cachoeiras de Macacu, Rio Bonito...
#
#   Bioma referencial (CGFUN) A UC possui plano de manejo (Sim / Não)  \
# 0          Marinho-Costeiro                                     Sim
# 1                   Cerrado                                     Não
# 2                   Cerrado                                     Sim
# 3                   Cerrado                                     Não
# 4            Mata Atlântica                                     Sim
#
#    Ano de elaboração do plano de manejo  \
# 0                                2013.0
# 1                                   NaN
# 2                                2014.0
# 3                                   NaN
# 4                                2008.0
#
#   O plano de manejo está em elaboração? (Sim / Não / NA)  \
# 0                                                NaN
# 1                                                Não
# 2                                                NaN
# 3                                                Não
# 4                                                NaN
#
#   O plano de manejo foi revisado? (Sim / Não / NA)
# 0                                              Não
# 1                                              NaN
# 2                                              Não
# 3                                              NaN
# 4                                              Não

# %%
fires_cols = ['Código CNUC',
              'Nome da UC',
              'Área queimada em 2012',
             'Área queimada em 2013',
             'Área queimada em 2014',
             'Área queimada em 2015',
             'Área queimada em 2016',
             'Área queimada em 2017']
fires_df = pd.read_csv(fires_path, encoding='latin-1', usecols=fires_cols)
fires_df.head()
# Out:
#     Código CNUC                                    Nome da UC  \
# 0  0000.00.0001                               APA Anhatomirim
# 1  0000.00.1521  APA Bacia Hidrográfica do Rio Paraíba do Sul
# 2  0000.00.0007                   APA Barra do Rio Mamanguape
# 3  0000.00.0020                     APA Carste da Lagoa Santa
# 4  0000.00.0002                       APA Cavernas do Peruaçu
#
#   Área queimada em 2017 Área queimada em 2016 Área queimada em 2015  \
# 0                   NaN                   NaN                   NaN
# 1                 182.1                   NaN                   NaN
# 2                   NaN                   NaN                   NaN
# 3                   NaN                   NaN                   NaN
# 4                 260.7                   NaN                   NaN
#
#   Área queimada em 2014 Área queimada em 2013 Área queimada em 2012
# 0                   NaN                   NaN                   NaN
# 1                   NaN                   NaN                   NaN
# 2                   NaN                   NaN                   NaN
# 3                   NaN                   NaN                   NaN
# 4                   NaN                   NaN                   NaN

# %%
visitation_sede_cols = ['cnuc',
                       'uc',
                       'sede_município-uf',
                       'sede_UF']
visitation_sede_df = pd.read_csv(visitation_sede_path, encoding = 'latin-1', usecols=visitation_sede_cols)
visitation_sede_df=visitation_sede_df.rename(columns={"cnuc":"Código CNUC", "uc":"Nome da UC"})
visitation_sede_df.head()
# Out:
#                      Nome da UC   Código CNUC  sede_município-uf sede_UF
# 0  ARIE Seringal Nova Esperança  0000.00.0044      Rio Branco/AC    Acre
# 1                 ESEC Rio Acre  0000.00.0068       Brasiléia/AC    Acre
# 2  FLONA de Santa Rosa do Purus  0000.00.0107      Rio Branco/AC    Acre
# 3        FLONA de São Francisco  0000.00.0108  Sena Madureira/AC    Acre
# 4               FLONA do Macauã  0000.00.0120  Sena Madureira/AC    Acre

# %%
visitation_total_mes_cols = ['cnuc',
                            'uc',
                            'mes_ano',
                            'total_mes']
visitation_total_mes_df = pd.read_csv(visitation_total_mes_path, encoding='latin-1', usecols=visitation_total_mes_cols)
visitation_total_mes_df=visitation_total_mes_df.rename(columns={"cnuc":"Código CNUC", "uc":"Nome da UC"})
visitation_total_mes_df.head()
# Out:
#     Código CNUC       Nome da UC   mes_ano total_mes
# 0  0000.00.0001  APA Anhatomirim  31/01/15    45,810
# 1  0000.00.0001  APA Anhatomirim  28/02/15    28,870
# 2  0000.00.0001  APA Anhatomirim  31/03/15    16,023
# 3  0000.00.0001  APA Anhatomirim  30/04/15    10,152
# 4  0000.00.0001  APA Anhatomirim  31/05/15     2,134

# %%
def proper_CNUC(df, PA):
    return df.loc[df["Nome da UC"]==PA, "Código CNUC"].iloc[0]

# %%
correct_CNUCs = []
for idx, row in council_df.iterrows():
    PA = row[1]
    correct_CNUCs.append(proper_CNUC(mp_df, PA))
correct_CNUCs = np.array(correct_CNUCs)

# %%
council_df["Código CNUC"] = correct_CNUCs
council_df.tail()
# Out:
#       Código CNUC                          Nome da UC  \
# 329  0000.00.3432  REVIS do Arquipélago de Alcatrazes
# 330  0000.00.1813             REVIS do Rio dos Frades
# 331  0000.00.0278          REVIS dos Campos de Palmas
# 332  0000.00.0190                REVIS Ilha dos Lobos
# 333  0000.00.3694                RVS da Ararinha Azul
#
#     Situação do Conselho\n(Instituído / Em formação / Inexistente)  \
# 329                                         Instituído
# 330                                         Instituído
# 331                                         Instituído
# 332                                         Instituído
# 333                                        Inexistente
#
#      Ano de instituição do Conselho\n(ano / NA)
# 329                                      2016.0
# 330                                      2011.0
# 331                                      2011.0
# 332                                      2016.0
# 333                                         NaN

# %% [markdown]
# # Creating Data Skeleton

# %%
council_CNUC_arr = list(council_df['Código CNUC'])
len(council_CNUC_arr)
# Out:
# 334

# %%
mp_CNUC_arr = list(mp_df['Código CNUC'])
len(mp_CNUC_arr)
# Out:
# 334

# %%
arr = np.setdiff1d(mp_CNUC_arr, council_CNUC_arr)
arr
# Out:
# array([], dtype='<U12')

# %%
master_df = pd.DataFrame(correct_CNUCs, columns=["CNUC"])
master_df.head()
# Out:
#            CNUC
# 0  0000.00.0001
# 1  0000.00.1521
# 2  0000.00.0007
# 3  0000.00.0020
# 4  0000.00.0002

# %%
master_df.shape
# Out:
# (334, 1)

# %%
PAs = []
for CNUC in master_df["CNUC"]:
    mp_PA = mp_df.loc[mp_df["Código CNUC"]==CNUC, "Nome da UC"].iloc[0]
    council_PA = council_df.loc[council_df["Código CNUC"]==CNUC, "Nome da UC"].iloc[0]
    assert mp_PA==council_PA
    PAs.append(mp_PA)
PAs = np.array(PAs)

# %%
master_df["PA"]=PAs
master_df
# Out:
#              CNUC                                            PA
# 0    0000.00.0001                               APA Anhatomirim
# 1    0000.00.1521  APA Bacia Hidrográfica do Rio Paraíba do Sul
# 2    0000.00.0007                   APA Barra do Rio Mamanguape
# 3    0000.00.0020                     APA Carste da Lagoa Santa
# 4    0000.00.0002                       APA Cavernas do Peruaçu
# ..            ...                                           ...
# 329  0000.00.3432            REVIS do Arquipélago de Alcatrazes
# 330  0000.00.1813                       REVIS do Rio dos Frades
# 331  0000.00.0278                    REVIS dos Campos de Palmas
# 332  0000.00.0190                          REVIS Ilha dos Lobos
# 333  0000.00.3694                          RVS da Ararinha Azul
#
# [334 rows x 2 columns]

# %%
def create_multiples(arr):
    multipled_arr = []
    
    for i in range(len(arr)):
        item = arr[i]
        # create 10 instances of each item to match the 10 PA-year indices that are needed
        multipled_arr.extend([item]*10)
    
    return multipled_arr

# %%
years = [2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017]*334
print(len(years))
# Out:
# 3340

# %%
multipled_CNUCS = create_multiples(correct_CNUCs)
multipled_PAs = create_multiples(PAs)
print(len(multipled_CNUCS))
print(len(multipled_PAs))
# Out:
# 3340
# 3340

# %%
final_df_cols = ["CNUC", "PA", "Year"]
final_df = pd.DataFrame(list(zip(multipled_CNUCS, multipled_PAs, years)), columns=final_df_cols)
final_df.head(10)
# Out:
#            CNUC               PA  Year
# 0  0000.00.0001  APA Anhatomirim  2008
# 1  0000.00.0001  APA Anhatomirim  2009
# 2  0000.00.0001  APA Anhatomirim  2010
# 3  0000.00.0001  APA Anhatomirim  2011
# 4  0000.00.0001  APA Anhatomirim  2012
# 5  0000.00.0001  APA Anhatomirim  2013
# 6  0000.00.0001  APA Anhatomirim  2014
# 7  0000.00.0001  APA Anhatomirim  2015
# 8  0000.00.0001  APA Anhatomirim  2016
# 9  0000.00.0001  APA Anhatomirim  2017

# %%
council_df.loc[council_df["Código CNUC"]=="0000.00.3694", "Ano de instituição do Conselho\n(ano / NA)"].isnull()
# Out:
# 333    True
# Name: Ano de instituição do Conselho\n(ano / NA), dtype: bool

# %%
council_df
# Out:
#       Código CNUC                                    Nome da UC  \
# 0    0000.00.0001                               APA Anhatomirim
# 1    0000.00.1521  APA Bacia Hidrográfica do Rio Paraíba do Sul
# 2    0000.00.0007                   APA Barra do Rio Mamanguape
# 3    0000.00.0020                     APA Carste da Lagoa Santa
# 4    0000.00.0002                       APA Cavernas do Peruaçu
# ..            ...                                           ...
# 329  0000.00.3432            REVIS do Arquipélago de Alcatrazes
# 330  0000.00.1813                       REVIS do Rio dos Frades
# 331  0000.00.0278                    REVIS dos Campos de Palmas
# 332  0000.00.0190                          REVIS Ilha dos Lobos
# 333  0000.00.3694                          RVS da Ararinha Azul
#
#     Situação do Conselho\n(Instituído / Em formação / Inexistente)  \
# 0                                           Instituído
# 1                                          Em formação
# 2                                           Instituído
# 3                                           Instituído
# 4                                           Instituído
# ..                                                 ...
# 329                                         Instituído
# 330                                         Instituído
# 331                                         Instituído
# 332                                         Instituído
# 333                                        Inexistente
#
#      Ano de instituição do Conselho\n(ano / NA)
# 0                                        2008.0
# 1                                           NaN
# 2                                        2005.0
# 3                                        2005.0
# 4                                        2004.0
# ..                                          ...
# 329                                      2016.0
# 330                                      2011.0
# 331                                      2011.0
# 332                                      2016.0
# 333                                         NaN
#
# [334 rows x 4 columns]

# %%
DF_SIZE = 334
def create_council_status(CNUCs, council_df):
    council_status = []
    council_creation_year = []
    
    for i in range(DF_SIZE):
        CNUC = CNUCs[i]
        year_created = council_df.loc[council_df["Código CNUC"]==CNUC, "Ano de instituição do Conselho\n(ano / NA)"].iloc[0]
        council_creation_year.extend([year_created]*10)
        
        if np.isnan(year_created) or year_created>2017:
            council_status.extend([0]*10)
        elif year_created<=2008:
            council_status.extend([1]*10)
        else:
            within_tf_arr = []
            for j in range(10):
                if year_created-2008<=j:
                    within_tf_arr.append(1)
                else:
                    within_tf_arr.append(0)
            council_status.extend(within_tf_arr)            
            
    return (council_status, council_creation_year)

# %%
council_status_arr, council_creation_year_arr = create_council_status(correct_CNUCs, council_df)
print(len(council_status_arr), len(council_creation_year_arr))
# Out:
# 3340 3340

# %%
final_df["council_status"] = council_status_arr
final_df["council_creation_year"] = council_creation_year_arr
final_df.head()
# Out:
#            CNUC               PA  Year  council_status  council_creation_year
# 0  0000.00.0001  APA Anhatomirim  2008               1                 2008.0
# 1  0000.00.0001  APA Anhatomirim  2009               1                 2008.0
# 2  0000.00.0001  APA Anhatomirim  2010               1                 2008.0
# 3  0000.00.0001  APA Anhatomirim  2011               1                 2008.0
# 4  0000.00.0001  APA Anhatomirim  2012               1                 2008.0

# %%
# tf = [2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017]
# j=0
# for i in range(20):
#     print("======", i, "=====")
#     for year in tf:
#         print(year, arr[j])
#         j+=1

# %%
def create_mp_df_arrs(CNUCs, mp_df):
    pa_creation_year_cmi = []
    reg_coord_2021 = []
    munis_covered_cmi = []
    biome_cmi = []
    mp_in_progress = []
    mp_revised = []
    
    for i in range(mp_df.shape[0]):
        CNUC = CNUCs[i]
        
        # pa_creation_year_cmi
        year = mp_df.loc[mp_df["Código CNUC"]==CNUC, "Ano de criação"].iloc[0]
        pa_creation_year_cmi.extend([year]*10)
        
        # reg_coord_2021
        coord = mp_df.loc[mp_df["Código CNUC"]==CNUC, "Coordenação Regional do ICMBio"].iloc[0]
        reg_coord_2021.extend([coord]*10)
        
        # munis_covered_cmi
        munis = mp_df.loc[mp_df["Código CNUC"]==CNUC, "Municípios sobrepostos"].iloc[0]
        munis_covered_cmi.extend([munis]*10)
        
        # biome_cmi
        biomes = mp_df.loc[mp_df["Código CNUC"]==CNUC, "Bioma referencial (CGFUN)"].iloc[0]
        biome_cmi.extend([biomes]*10)
        
        # mp_in_progress
        in_prog = mp_df.loc[mp_df["Código CNUC"]==CNUC, "O plano de manejo está em elaboração? (Sim / Não / NA)"].iloc[0]
        mp_in_progress.extend([in_prog]*10)
        
        # mp_revised
        revised = mp_df.loc[mp_df["Código CNUC"]==CNUC, "O plano de manejo foi revisado? (Sim / Não / NA)"].iloc[0]
        mp_revised.extend([revised]*10)
        
    return (pa_creation_year_cmi, reg_coord_2021, munis_covered_cmi, biome_cmi, mp_in_progress, mp_revised)

# %%
pa_creation_year_cmi_arr, reg_coord_2021_arr, munis_covered_cmi_arr, biome_cmi_arr, mp_in_progress_arr, mp_revised_arr = create_mp_df_arrs(correct_CNUCs, mp_df)

# %%
len(pa_creation_year_cmi_arr)
# Out:
# 3340

# %%
final_df["pa_creation_year_cmi"] = pa_creation_year_cmi_arr
final_df["reg_coord_2021"] = reg_coord_2021_arr
final_df["munis_covered_cmi"] = munis_covered_cmi_arr
final_df["biome_cmi"] = biome_cmi_arr
final_df.head(30)
# Out:
#             CNUC                                            PA  Year  \
# 0   0000.00.0001                               APA Anhatomirim  2008
# 1   0000.00.0001                               APA Anhatomirim  2009
# 2   0000.00.0001                               APA Anhatomirim  2010
# 3   0000.00.0001                               APA Anhatomirim  2011
# 4   0000.00.0001                               APA Anhatomirim  2012
# 5   0000.00.0001                               APA Anhatomirim  2013
# 6   0000.00.0001                               APA Anhatomirim  2014
# 7   0000.00.0001                               APA Anhatomirim  2015
# 8   0000.00.0001                               APA Anhatomirim  2016
# 9   0000.00.0001                               APA Anhatomirim  2017
# 10  0000.00.1521  APA Bacia Hidrográfica do Rio Paraíba do Sul  2008
# 11  0000.00.1521  APA Bacia Hidrográfica do Rio Paraíba do Sul  2009
# 12  0000.00.1521  APA Bacia Hidrográfica do Rio Paraíba do Sul  2010
# 13  0000.00.1521  APA Bacia Hidrográfica do Rio Paraíba do Sul  2011
# 14  0000.00.1521  APA Bacia Hidrográfica do Rio Paraíba do Sul  2012
# 15  0000.00.1521  APA Bacia Hidrográfica do Rio Paraíba do Sul  2013
# 16  0000.00.1521  APA Bacia Hidrográfica do Rio Paraíba do Sul  2014
# 17  0000.00.1521  APA Bacia Hidrográfica do Rio Paraíba do Sul  2015
# 18  0000.00.1521  APA Bacia Hidrográfica do Rio Paraíba do Sul  2016
# 19  0000.00.1521  APA Bacia Hidrográfica do Rio Paraíba do Sul  2017
# 20  0000.00.0007                   APA Barra do Rio Mamanguape  2008
# 21  0000.00.0007                   APA Barra do Rio Mamanguape  2009
# 22  0000.00.0007                   APA Barra do Rio Mamanguape  2010
# 23  0000.00.0007                   APA Barra do Rio Mamanguape  2011
# 24  0000.00.0007                   APA Barra do Rio Mamanguape  2012
# 25  0000.00.0007                   APA Barra do Rio Mamanguape  2013
# 26  0000.00.0007                   APA Barra do Rio Mamanguape  2014
# 27  0000.00.0007                   APA Barra do Rio Mamanguape  2015
# 28  0000.00.0007                   APA Barra do Rio Mamanguape  2016
# 29  0000.00.0007                   APA Barra do Rio Mamanguape  2017
#
#     council_status  council_creation_year  pa_creation_year_cmi  \
# 0                1                 2008.0                  1992
# 1                1                 2008.0                  1992
# 2                1                 2008.0                  1992
# 3                1                 2008.0                  1992
# 4                1                 2008.0                  1992
# 5                1                 2008.0                  1992
# 6                1                 2008.0                  1992
# 7                1                 2008.0                  1992
# 8                1                 2008.0                  1992
# 9                1                 2008.0                  1992
# 10               0                    NaN                  1982
# 11               0                    NaN                  1982
# 12               0                    NaN                  1982
# 13               0                    NaN                  1982
# 14               0                    NaN                  1982
# 15               0                    NaN                  1982
# 16               0                    NaN                  1982
# 17               0                    NaN                  1982
# 18               0                    NaN                  1982
# 19               0                    NaN                  1982
# 20               1                 2005.0                  1993
# 21               1                 2005.0                  1993
# 22               1                 2005.0                  1993
# 23               1                 2005.0                  1993
# 24               1                 2005.0                  1993
# 25               1                 2005.0                  1993
# 26               1                 2005.0                  1993
# 27               1                 2005.0                  1993
# 28               1                 2005.0                  1993
# 29               1                 2005.0                  1993
#
#            reg_coord_2021                                  munis_covered_cmi  \
# 0    CR9 Florianópolis/SC                             Governador Celso Ramos
# 1    CR9 Florianópolis/SC                             Governador Celso Ramos
# 2    CR9 Florianópolis/SC                             Governador Celso Ramos
# 3    CR9 Florianópolis/SC                             Governador Celso Ramos
# 4    CR9 Florianópolis/SC                             Governador Celso Ramos
# 5    CR9 Florianópolis/SC                             Governador Celso Ramos
# 6    CR9 Florianópolis/SC                             Governador Celso Ramos
# 7    CR9 Florianópolis/SC                             Governador Celso Ramos
# 8    CR9 Florianópolis/SC                             Governador Celso Ramos
# 9    CR9 Florianópolis/SC                             Governador Celso Ramos
# 10  CR8 Rio de Janeiro/RJ  Silveiras, Taubaté, Ubatuba, Parati, Areias, A...
# 11  CR8 Rio de Janeiro/RJ  Silveiras, Taubaté, Ubatuba, Parati, Areias, A...
# 12  CR8 Rio de Janeiro/RJ  Silveiras, Taubaté, Ubatuba, Parati, Areias, A...
# 13  CR8 Rio de Janeiro/RJ  Silveiras, Taubaté, Ubatuba, Parati, Areias, A...
# 14  CR8 Rio de Janeiro/RJ  Silveiras, Taubaté, Ubatuba, Parati, Areias, A...
# 15  CR8 Rio de Janeiro/RJ  Silveiras, Taubaté, Ubatuba, Parati, Areias, A...
# 16  CR8 Rio de Janeiro/RJ  Silveiras, Taubaté, Ubatuba, Parati, Areias, A...
# 17  CR8 Rio de Janeiro/RJ  Silveiras, Taubaté, Ubatuba, Parati, Areias, A...
# 18  CR8 Rio de Janeiro/RJ  Silveiras, Taubaté, Ubatuba, Parati, Areias, A...
# 19  CR8 Rio de Janeiro/RJ  Silveiras, Taubaté, Ubatuba, Parati, Areias, A...
# 20        CR6 Cabedelo/PB       Rio Tinto, Lucena, Marcação, Baía da Traição
# 21        CR6 Cabedelo/PB       Rio Tinto, Lucena, Marcação, Baía da Traição
# 22        CR6 Cabedelo/PB       Rio Tinto, Lucena, Marcação, Baía da Traição
# 23        CR6 Cabedelo/PB       Rio Tinto, Lucena, Marcação, Baía da Traição
# 24        CR6 Cabedelo/PB       Rio Tinto, Lucena, Marcação, Baía da Traição
# 25        CR6 Cabedelo/PB       Rio Tinto, Lucena, Marcação, Baía da Traição
# 26        CR6 Cabedelo/PB       Rio Tinto, Lucena, Marcação, Baía da Traição
# 27        CR6 Cabedelo/PB       Rio Tinto, Lucena, Marcação, Baía da Traição
# 28        CR6 Cabedelo/PB       Rio Tinto, Lucena, Marcação, Baía da Traição
# 29        CR6 Cabedelo/PB       Rio Tinto, Lucena, Marcação, Baía da Traição
#
#            biome_cmi
# 0   Marinho-Costeiro
# 1   Marinho-Costeiro
# 2   Marinho-Costeiro
# 3   Marinho-Costeiro
# 4   Marinho-Costeiro
# 5   Marinho-Costeiro
# 6   Marinho-Costeiro
# 7   Marinho-Costeiro
# 8   Marinho-Costeiro
# 9   Marinho-Costeiro
# 10    Mata Atlântica
# 11    Mata Atlântica
# 12    Mata Atlântica
# 13    Mata Atlântica
# 14    Mata Atlântica
# 15    Mata Atlântica
# 16    Mata Atlântica
# 17    Mata Atlântica
# 18    Mata Atlântica
# 19    Mata Atlântica
# 20  Marinho-Costeiro
# 21  Marinho-Costeiro
# 22  Marinho-Costeiro
# 23  Marinho-Costeiro
# 24  Marinho-Costeiro
# 25  Marinho-Costeiro
# 26  Marinho-Costeiro
# 27  Marinho-Costeiro
# 28  Marinho-Costeiro
# 29  Marinho-Costeiro

# %%
mp_df
# Out:
#       Código CNUC                                        Nome da UC  \
# 0    0000.00.0001                                   APA Anhatomirim
# 1    0000.00.0002                           APA Cavernas do Peruaçu
# 2    0000.00.0003                    APA da Bacia do Rio Descoberto
# 3    0000.00.0004                APA da Bacia do Rio São Bartolomeu
# 4    0000.00.0005  APA da Bacia do Rio São João - Mico-Leão-Dourado
# ..            ...                                               ...
# 329  0000.00.3654                           RESEX Apapiranga-Tromai
# 330  0000.00.3655                          APA do Boqueirao da onça
# 331  0000.00.3693                   RESEX Baixo Rio Branco-Jauaperi
# 332  0000.00.3694                              RVS da Ararinha Azul
# 333  0000.00.3696                              APA da Ararinha Azul
#
#      Ano de criação Coordenação Regional do ICMBio  \
# 0              1992           CR9 Florianópolis/SC
# 1              1989            CR11 Lagoa Santa/MG
# 2              1983            CR11 Lagoa Santa/MG
# 3              1983            CR11 Lagoa Santa/MG
# 4              2002          CR8 Rio de Janeiro/RJ
# ..              ...                            ...
# 329            2018                   CR4 Belém/PA
# 330            2018                CR6 Cabedelo/PB
# 331            2018                  CR2 Manaus/AM
# 332            2018                CR6 Cabedelo/PB
# 333            2018                CR6 Cabedelo/PB
#
#                                 Municípios sobrepostos  \
# 0                               Governador Celso Ramos
# 1    Bonito de Minas, Cônego Marinho, Januária, Ita...
# 2      Brasília, Águas Lindas de Goiás, Padre Bernardo
# 3                                             Brasília
# 4    Silva Jardim, Cachoeiras de Macacu, Rio Bonito...
# ..                                                 ...
# 329                   Carutapera/MA, Luís Domingues/MA
# 330  Sento Sé/BA, Juazeiro/BA, Sobradinho/BA, Campo...
# 331                     Rorainópolis/RO, Novo Airão/AM
# 332                             Juazeiro/BA, Curaçá/BA
# 333                             Juazeiro/BA, Curaçá/BA
#
#     Bioma referencial (CGFUN) A UC possui plano de manejo (Sim / Não)  \
# 0            Marinho-Costeiro                                     Sim
# 1                     Cerrado                                     Não
# 2                     Cerrado                                     Sim
# 3                     Cerrado                                     Não
# 4              Mata Atlântica                                     Sim
# ..                        ...                                     ...
# 329          Marinho-Costeiro                                     Não
# 330                  Caatinga                                     Não
# 331                  Amazônia                                     Não
# 332                  Caatinga                                     Não
# 333                  Caatinga                                     Não
#
#      Ano de elaboração do plano de manejo  \
# 0                                  2013.0
# 1                                     NaN
# 2                                  2014.0
# 3                                     NaN
# 4                                  2008.0
# ..                                    ...
# 329                                   NaN
# 330                                   NaN
# 331                                   NaN
# 332                                   NaN
# 333                                   NaN
#
#     O plano de manejo está em elaboração? (Sim / Não / NA)  \
# 0                                                  NaN
# 1                                                  Não
# 2                                                  NaN
# 3                                                  Não
# 4                                                  NaN
# ..                                                 ...
# 329                                                Não
# 330                                                Não
# 331                                                Não
# 332                                                Não
# 333                                                Não
#
#     O plano de manejo foi revisado? (Sim / Não / NA)
# 0                                                Não
# 1                                                NaN
# 2                                                Não
# 3                                                NaN
# 4                                                Não
# ..                                               ...
# 329                                              NaN
# 330                                              NaN
# 331                                              NaN
# 332                                              NaN
# 333                                              NaN
#
# [334 rows x 10 columns]

# %%
DF_SIZE = 334
def create_mp_cmi(CNUCs, mp_df):
    mp_cmi = []
    mp_creation_year_cmi = []
    
    for i in range(DF_SIZE):
        CNUC = CNUCs[i]
        year_created = mp_df.loc[mp_df["Código CNUC"]==CNUC, "Ano de elaboração do plano de manejo"].iloc[0]
        mp_creation_year_cmi.extend([year_created]*10)
        
        if np.isnan(year_created) or year_created>2017:
            mp_cmi.extend([0]*10)
        elif year_created<=2008:
            mp_cmi.extend([1]*10)
        else:
            within_tf_arr = []
            for j in range(10):
                if year_created-2008<=j:
                    within_tf_arr.append(1)
                else:
                    within_tf_arr.append(0)
            mp_cmi.extend(within_tf_arr)            
            
    return (mp_cmi, mp_creation_year_cmi)

# %%
mp_cmi_arr, mp_creation_year_cmi_arr = create_mp_cmi(correct_CNUCs, mp_df)
print(len(mp_cmi_arr), len(mp_creation_year_cmi_arr))
# Out:
# 3340 3340

# %%
final_df["mp_cmi"] = mp_cmi_arr
final_df["mp_creation_year_cmi"] = mp_creation_year_cmi_arr
final_df.head()
# Out:
#            CNUC               PA  Year  council_status  council_creation_year  \
# 0  0000.00.0001  APA Anhatomirim  2008               1                 2008.0
# 1  0000.00.0001  APA Anhatomirim  2009               1                 2008.0
# 2  0000.00.0001  APA Anhatomirim  2010               1                 2008.0
# 3  0000.00.0001  APA Anhatomirim  2011               1                 2008.0
# 4  0000.00.0001  APA Anhatomirim  2012               1                 2008.0
#
#    pa_creation_year_cmi        reg_coord_2021       munis_covered_cmi  \
# 0                  1992  CR9 Florianópolis/SC  Governador Celso Ramos
# 1                  1992  CR9 Florianópolis/SC  Governador Celso Ramos
# 2                  1992  CR9 Florianópolis/SC  Governador Celso Ramos
# 3                  1992  CR9 Florianópolis/SC  Governador Celso Ramos
# 4                  1992  CR9 Florianópolis/SC  Governador Celso Ramos
#
#           biome_cmi  mp_cmi  mp_creation_year_cmi
# 0  Marinho-Costeiro       0                2013.0
# 1  Marinho-Costeiro       0                2013.0
# 2  Marinho-Costeiro       0                2013.0
# 3  Marinho-Costeiro       0                2013.0
# 4  Marinho-Costeiro       0                2013.0

# %%
final_df["mp_in_progress"] = mp_in_progress_arr
final_df["mp_revised"] = mp_revised_arr
final_df.head()
# Out:
#            CNUC               PA  Year  council_status  council_creation_year  \
# 0  0000.00.0001  APA Anhatomirim  2008               1                 2008.0
# 1  0000.00.0001  APA Anhatomirim  2009               1                 2008.0
# 2  0000.00.0001  APA Anhatomirim  2010               1                 2008.0
# 3  0000.00.0001  APA Anhatomirim  2011               1                 2008.0
# 4  0000.00.0001  APA Anhatomirim  2012               1                 2008.0
#
#    pa_creation_year_cmi        reg_coord_2021       munis_covered_cmi  \
# 0                  1992  CR9 Florianópolis/SC  Governador Celso Ramos
# 1                  1992  CR9 Florianópolis/SC  Governador Celso Ramos
# 2                  1992  CR9 Florianópolis/SC  Governador Celso Ramos
# 3                  1992  CR9 Florianópolis/SC  Governador Celso Ramos
# 4                  1992  CR9 Florianópolis/SC  Governador Celso Ramos
#
#           biome_cmi  mp_cmi  mp_creation_year_cmi mp_in_progress mp_revised
# 0  Marinho-Costeiro       0                2013.0            NaN        Não
# 1  Marinho-Costeiro       0                2013.0            NaN        Não
# 2  Marinho-Costeiro       0                2013.0            NaN        Não
# 3  Marinho-Costeiro       0                2013.0            NaN        Não
# 4  Marinho-Costeiro       0                2013.0            NaN        Não

# %%
visitation_sede_df
# Out:
#                        Nome da UC   Código CNUC  sede_município-uf  \
# 0    ARIE Seringal Nova Esperança  0000.00.0044      Rio Branco/AC
# 1                   ESEC Rio Acre  0000.00.0068       Brasiléia/AC
# 2    FLONA de Santa Rosa do Purus  0000.00.0107      Rio Branco/AC
# 3          FLONA de São Francisco  0000.00.0108  Sena Madureira/AC
# 4                 FLONA do Macauã  0000.00.0120  Sena Madureira/AC
# ..                            ...           ...                ...
# 329     ARIE Buriti de Vassununga  0000.00.0030                NaN
# 330        ARIE Capetinga-Taquara  0000.00.0031                NaN
# 331    ARIE Cerrado Pé-de-Gigante  0000.00.0032                NaN
# 332             ESEC do Castanhão  0000.00.0066                NaN
# 333          FLONA de Cristópolis  0000.00.0090                NaN
#
#               sede_UF
# 0                Acre
# 1                Acre
# 2                Acre
# 3                Acre
# 4                Acre
# ..                ...
# 329         São Paulo
# 330  Distrito Federal
# 331         São Paulo
# 332             Ceara
# 333             Bahia
#
# [334 rows x 4 columns]

# %%
def create_visitation_df_arrs(CNUCs, visitation_df):
    management_muni_cmi = []
    management_state_cmi = []
    
    for i in range(mp_df.shape[0]):
        CNUC = CNUCs[i]
        
        # management_muni_cmi
        muni_cmi = visitation_df.loc[visitation_df["Código CNUC"]==CNUC, "sede_município-uf"].iloc[0]
        
        # cut off the state codes
        try:
            muni_cmi = muni_cmi.split("/")[0]
        except:
            pass
            
        management_muni_cmi.extend([muni_cmi]*10)
        
        # management_state_cmi
        state_cmi = visitation_df.loc[visitation_df["Código CNUC"]==CNUC, "sede_UF"].iloc[0]
        management_state_cmi.extend([state_cmi]*10)
        
    return (management_muni_cmi, management_state_cmi)

# %%
management_muni_cmi_arr, management_state_cmi_arr = create_visitation_df_arrs(correct_CNUCs, visitation_sede_df)
print(len(management_muni_cmi_arr), len(management_state_cmi_arr))
# Out:
# 3340 3340

# %%
final_df["management_muni_cmi"] = management_muni_cmi_arr
final_df["management_state_cmi"] = management_state_cmi_arr
final_df.head()
# Out:
#            CNUC               PA  Year  council_status  council_creation_year  \
# 0  0000.00.0001  APA Anhatomirim  2008               1                 2008.0
# 1  0000.00.0001  APA Anhatomirim  2009               1                 2008.0
# 2  0000.00.0001  APA Anhatomirim  2010               1                 2008.0
# 3  0000.00.0001  APA Anhatomirim  2011               1                 2008.0
# 4  0000.00.0001  APA Anhatomirim  2012               1                 2008.0
#
#    pa_creation_year_cmi        reg_coord_2021       munis_covered_cmi  \
# 0                  1992  CR9 Florianópolis/SC  Governador Celso Ramos
# 1                  1992  CR9 Florianópolis/SC  Governador Celso Ramos
# 2                  1992  CR9 Florianópolis/SC  Governador Celso Ramos
# 3                  1992  CR9 Florianópolis/SC  Governador Celso Ramos
# 4                  1992  CR9 Florianópolis/SC  Governador Celso Ramos
#
#           biome_cmi  mp_cmi  mp_creation_year_cmi mp_in_progress mp_revised  \
# 0  Marinho-Costeiro       0                2013.0            NaN        Não
# 1  Marinho-Costeiro       0                2013.0            NaN        Não
# 2  Marinho-Costeiro       0                2013.0            NaN        Não
# 3  Marinho-Costeiro       0                2013.0            NaN        Não
# 4  Marinho-Costeiro       0                2013.0            NaN        Não
#
#   management_muni_cmi management_state_cmi
# 0       Florianópolis       Santa Catarina
# 1       Florianópolis       Santa Catarina
# 2       Florianópolis       Santa Catarina
# 3       Florianópolis       Santa Catarina
# 4       Florianópolis       Santa Catarina

# %%
int_nums = []

for str_num in visitation_total_mes_df["total_mes"]:
    try:
        int_num = int(str_num.replace("," , ""))
    # using 0 for NaN entries
    except:
        int_num = 0
    int_nums.append(int_num)

visitation_total_mes_df["total_mes_int"] = int_nums
visitation_total_mes_df.head()
# Out:
#     Código CNUC       Nome da UC   mes_ano total_mes  total_mes_int
# 0  0000.00.0001  APA Anhatomirim  31/01/15    45,810          45810
# 1  0000.00.0001  APA Anhatomirim  28/02/15    28,870          28870
# 2  0000.00.0001  APA Anhatomirim  31/03/15    16,023          16023
# 3  0000.00.0001  APA Anhatomirim  30/04/15    10,152          10152
# 4  0000.00.0001  APA Anhatomirim  31/05/15     2,134           2134

# %%
# only 160 CNUC with data, so must fill in rest with 0s
visitation_total_mes_df["Código CNUC"].nunique()
# Out:
# 160

# %%
def create_visitors(CNUCs, visitation_total_mes_df):
    visitors = []
    for i in range(mp_df.shape[0]):
        CNUC = CNUCs[i]
        
        visitation_df = visitation_total_mes_df.groupby("Código CNUC").sum()
        visitation_df = visitation_df.reset_index()
        
        # cut off the state codes
        visitor_val = 0
        try:
            visitor_val = visitation_df.loc[visitation_df["Código CNUC"]==CNUC, "total_mes_int"].iloc[0]
        except:
            pass
        
        visitors.extend([visitor_val]*10)
        
    return visitors

# %%
visitors_arr = create_visitors(correct_CNUCs, visitation_total_mes_df)
print(len(visitors_arr))
# Out:
# 3340

# %%
final_df["visitors"] = visitors_arr
final_df.head()
# Out:
#            CNUC               PA  Year  council_status  council_creation_year  \
# 0  0000.00.0001  APA Anhatomirim  2008               1                 2008.0
# 1  0000.00.0001  APA Anhatomirim  2009               1                 2008.0
# 2  0000.00.0001  APA Anhatomirim  2010               1                 2008.0
# 3  0000.00.0001  APA Anhatomirim  2011               1                 2008.0
# 4  0000.00.0001  APA Anhatomirim  2012               1                 2008.0
#
#    pa_creation_year_cmi        reg_coord_2021       munis_covered_cmi  \
# 0                  1992  CR9 Florianópolis/SC  Governador Celso Ramos
# 1                  1992  CR9 Florianópolis/SC  Governador Celso Ramos
# 2                  1992  CR9 Florianópolis/SC  Governador Celso Ramos
# 3                  1992  CR9 Florianópolis/SC  Governador Celso Ramos
# 4                  1992  CR9 Florianópolis/SC  Governador Celso Ramos
#
#           biome_cmi  mp_cmi  mp_creation_year_cmi mp_in_progress mp_revised  \
# 0  Marinho-Costeiro       0                2013.0            NaN        Não
# 1  Marinho-Costeiro       0                2013.0            NaN        Não
# 2  Marinho-Costeiro       0                2013.0            NaN        Não
# 3  Marinho-Costeiro       0                2013.0            NaN        Não
# 4  Marinho-Costeiro       0                2013.0            NaN        Não
#
#   management_muni_cmi management_state_cmi  visitors
# 0       Florianópolis       Santa Catarina    784184
# 1       Florianópolis       Santa Catarina    784184
# 2       Florianópolis       Santa Catarina    784184
# 3       Florianópolis       Santa Catarina    784184
# 4       Florianópolis       Santa Catarina    784184

# %%
fires_df
# Out:
#       Código CNUC                                    Nome da UC  \
# 0    0000.00.0001                               APA Anhatomirim
# 1    0000.00.1521  APA Bacia Hidrográfica do Rio Paraíba do Sul
# 2    0000.00.0007                   APA Barra do Rio Mamanguape
# 3    0000.00.0020                     APA Carste da Lagoa Santa
# 4    0000.00.0002                       APA Cavernas do Peruaçu
# ..            ...                                           ...
# 320  0000.00.1880                                  REVIS de Una
# 321  0000.00.3432            REVIS do Arquipélago de Alcatrazes
# 322  0000.00.1813                       REVIS do Rio dos Frades
# 323  0000.00.0278                    REVIS dos Campos de Palmas
# 324  0000.00.0190                          REVIS Ilha dos Lobos
#
#     Área queimada em 2017 Área queimada em 2016 Área queimada em 2015  \
# 0                     NaN                   NaN                   NaN
# 1                   182.1                   NaN                   NaN
# 2                     NaN                   NaN                   NaN
# 3                     NaN                   NaN                   NaN
# 4                   260.7                   NaN                   NaN
# ..                    ...                   ...                   ...
# 320                   NaN                   NaN                   NaN
# 321                   NaN                   NaN                   NaN
# 322                   NaN                   NaN                   NaN
# 323                 109.5               3,249.5                   NaN
# 324                   NaN                   NaN                   NaN
#
#     Área queimada em 2014 Área queimada em 2013 Área queimada em 2012
# 0                     NaN                   NaN                   NaN
# 1                     NaN                   NaN                   NaN
# 2                     NaN                   NaN                   NaN
# 3                     NaN                   NaN                   NaN
# 4                     NaN                   NaN                   NaN
# ..                    ...                   ...                   ...
# 320                   NaN                   NaN                   NaN
# 321                   NaN                   NaN                   NaN
# 322                   NaN                   NaN                   NaN
# 323                   NaN                   NaN                   NaN
# 324                   NaN                   NaN                   NaN
#
# [325 rows x 8 columns]

# %%
def create_fire_arrs(CNUCs, fires_df):
    area_burned_2017 = []
    area_burned_2016 = []
    area_burned_2015 = []
    area_burned_2014 = []
    area_burned_2013 = []
    area_burned_2012 = []
    
    for i in range(mp_df.shape[0]):
        CNUC = CNUCs[i]
        
        # 2017
        area_2017 = np.nan
        try:
            area_2017 = fires_df.loc[fires_df["Código CNUC"]==CNUC, "Área queimada em 2017"].iloc[0]
        except:
            pass
        area_burned_2017.extend([area_2017]*10)
        
        # 2016
        area_2016 = np.nan
        try:
            area_2016 = fires_df.loc[fires_df["Código CNUC"]==CNUC, "Área queimada em 2016"].iloc[0]
        except:
            pass
        area_burned_2016.extend([area_2016]*10)
        
        # 2015
        area_2015 = np.nan
        try:
            area_2015 = fires_df.loc[fires_df["Código CNUC"]==CNUC, "Área queimada em 2015"].iloc[0]
        except:
            pass
        area_burned_2015.extend([area_2015]*10)
        
        # 2014
        area_2014 = np.nan
        try:
            area_2014 = fires_df.loc[fires_df["Código CNUC"]==CNUC, "Área queimada em 2014"].iloc[0]
        except:
            pass
        area_burned_2014.extend([area_2014]*10)
        
        # 2013
        area_2013 = np.nan
        try:
            area_2013 = fires_df.loc[fires_df["Código CNUC"]==CNUC, "Área queimada em 2013"].iloc[0]
        except:
            pass
        area_burned_2013.extend([area_2013]*10)
        
        # 2012
        area_2012 = np.nan
        try:
            area_2012 = fires_df.loc[fires_df["Código CNUC"]==CNUC, "Área queimada em 2012"].iloc[0]
        except:
            pass
        area_burned_2012.extend([area_2012]*10)
        
    return (area_burned_2017, area_burned_2016, area_burned_2015, area_burned_2014, area_burned_2013, area_burned_2012)

# %%
area_burned_2017_arr, area_burned_2016_arr, area_burned_2015_arr, area_burned_2014_arr, area_burned_2013_arr, area_burned_2012_arr = create_fire_arrs(correct_CNUCs, fires_df)
len(area_burned_2013_arr)
# Out:
# 3340

# %%
final_df["area_burned_2017"] = area_burned_2017_arr
final_df["area_burned_2016"] = area_burned_2016_arr
final_df["area_burned_2015"] = area_burned_2015_arr
final_df["area_burned_2014"] = area_burned_2014_arr
final_df["area_burned_2013"] = area_burned_2013_arr
final_df["area_burned_2012"] = area_burned_2012_arr
final_df.head()
# Out:
#            CNUC               PA  Year  council_status  council_creation_year  \
# 0  0000.00.0001  APA Anhatomirim  2008               1                 2008.0
# 1  0000.00.0001  APA Anhatomirim  2009               1                 2008.0
# 2  0000.00.0001  APA Anhatomirim  2010               1                 2008.0
# 3  0000.00.0001  APA Anhatomirim  2011               1                 2008.0
# 4  0000.00.0001  APA Anhatomirim  2012               1                 2008.0
#
#    pa_creation_year_cmi        reg_coord_2021       munis_covered_cmi  \
# 0                  1992  CR9 Florianópolis/SC  Governador Celso Ramos
# 1                  1992  CR9 Florianópolis/SC  Governador Celso Ramos
# 2                  1992  CR9 Florianópolis/SC  Governador Celso Ramos
# 3                  1992  CR9 Florianópolis/SC  Governador Celso Ramos
# 4                  1992  CR9 Florianópolis/SC  Governador Celso Ramos
#
#           biome_cmi  mp_cmi  ...  mp_revised management_muni_cmi  \
# 0  Marinho-Costeiro       0  ...         Não       Florianópolis
# 1  Marinho-Costeiro       0  ...         Não       Florianópolis
# 2  Marinho-Costeiro       0  ...         Não       Florianópolis
# 3  Marinho-Costeiro       0  ...         Não       Florianópolis
# 4  Marinho-Costeiro       0  ...         Não       Florianópolis
#
#   management_state_cmi visitors area_burned_2017  area_burned_2016  \
# 0       Santa Catarina   784184              NaN               NaN
# 1       Santa Catarina   784184              NaN               NaN
# 2       Santa Catarina   784184              NaN               NaN
# 3       Santa Catarina   784184              NaN               NaN
# 4       Santa Catarina   784184              NaN               NaN
#
#   area_burned_2015 area_burned_2014 area_burned_2013 area_burned_2012
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN              NaN              NaN
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              NaN              NaN              NaN              NaN
#
# [5 rows x 22 columns]

# %%
final_df
# Out:
#               CNUC                    PA  Year  council_status  \
# 0     0000.00.0001       APA Anhatomirim  2008               1
# 1     0000.00.0001       APA Anhatomirim  2009               1
# 2     0000.00.0001       APA Anhatomirim  2010               1
# 3     0000.00.0001       APA Anhatomirim  2011               1
# 4     0000.00.0001       APA Anhatomirim  2012               1
# ...            ...                   ...   ...             ...
# 3335  0000.00.3694  RVS da Ararinha Azul  2013               0
# 3336  0000.00.3694  RVS da Ararinha Azul  2014               0
# 3337  0000.00.3694  RVS da Ararinha Azul  2015               0
# 3338  0000.00.3694  RVS da Ararinha Azul  2016               0
# 3339  0000.00.3694  RVS da Ararinha Azul  2017               0
#
#       council_creation_year  pa_creation_year_cmi        reg_coord_2021  \
# 0                    2008.0                  1992  CR9 Florianópolis/SC
# 1                    2008.0                  1992  CR9 Florianópolis/SC
# 2                    2008.0                  1992  CR9 Florianópolis/SC
# 3                    2008.0                  1992  CR9 Florianópolis/SC
# 4                    2008.0                  1992  CR9 Florianópolis/SC
# ...                     ...                   ...                   ...
# 3335                    NaN                  2018       CR6 Cabedelo/PB
# 3336                    NaN                  2018       CR6 Cabedelo/PB
# 3337                    NaN                  2018       CR6 Cabedelo/PB
# 3338                    NaN                  2018       CR6 Cabedelo/PB
# 3339                    NaN                  2018       CR6 Cabedelo/PB
#
#            munis_covered_cmi         biome_cmi  mp_cmi  ...  mp_revised  \
# 0     Governador Celso Ramos  Marinho-Costeiro       0  ...         Não
# 1     Governador Celso Ramos  Marinho-Costeiro       0  ...         Não
# 2     Governador Celso Ramos  Marinho-Costeiro       0  ...         Não
# 3     Governador Celso Ramos  Marinho-Costeiro       0  ...         Não
# 4     Governador Celso Ramos  Marinho-Costeiro       0  ...         Não
# ...                      ...               ...     ...  ...         ...
# 3335  Juazeiro/BA, Curaçá/BA          Caatinga       0  ...         NaN
# 3336  Juazeiro/BA, Curaçá/BA          Caatinga       0  ...         NaN
# 3337  Juazeiro/BA, Curaçá/BA          Caatinga       0  ...         NaN
# 3338  Juazeiro/BA, Curaçá/BA          Caatinga       0  ...         NaN
# 3339  Juazeiro/BA, Curaçá/BA          Caatinga       0  ...         NaN
#
#      management_muni_cmi management_state_cmi visitors area_burned_2017  \
# 0          Florianópolis       Santa Catarina   784184              NaN
# 1          Florianópolis       Santa Catarina   784184              NaN
# 2          Florianópolis       Santa Catarina   784184              NaN
# 3          Florianópolis       Santa Catarina   784184              NaN
# 4          Florianópolis       Santa Catarina   784184              NaN
# ...                  ...                  ...      ...              ...
# 3335            Juazeiro                Bahia        0              NaN
# 3336            Juazeiro                Bahia        0              NaN
# 3337            Juazeiro                Bahia        0              NaN
# 3338            Juazeiro                Bahia        0              NaN
# 3339            Juazeiro                Bahia        0              NaN
#
#       area_burned_2016 area_burned_2015 area_burned_2014 area_burned_2013  \
# 0                  NaN              NaN              NaN              NaN
# 1                  NaN              NaN              NaN              NaN
# 2                  NaN              NaN              NaN              NaN
# 3                  NaN              NaN              NaN              NaN
# 4                  NaN              NaN              NaN              NaN
# ...                ...              ...              ...              ...
# 3335               NaN              NaN              NaN              NaN
# 3336               NaN              NaN              NaN              NaN
# 3337               NaN              NaN              NaN              NaN
# 3338               NaN              NaN              NaN              NaN
# 3339               NaN              NaN              NaN              NaN
#
#      area_burned_2012
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 3335              NaN
# 3336              NaN
# 3337              NaN
# 3338              NaN
# 3339              NaN
#
# [3340 rows x 22 columns]

# %%
final_df.to_csv("performance_analysis_data.csv", na_rep = "NaN", encoding='utf-8-sig', index=False)
